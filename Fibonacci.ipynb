# %% [markdown]
# <a href="https://colab.research.google.com/github/snehavyshnavi/Python/blob/main/Fibonacci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter how many terms: "))
a, b = 0, 1

print("Fibonacci Series:")
for _ in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter how many terms: 5
# Fibonacci Series:
# 0 1 1 2 3
