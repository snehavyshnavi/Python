# %% [markdown]
# <a href="https://colab.research.google.com/github/snehavyshnavi/Python/blob/main/RockPaperscissorgame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

options = ["rock", "paper", "scissors"]
user = input("Enter choice (rock/paper/scissors): ").lower()
computer = random.choice(options)

print("Computer chose:", computer)

if user == computer:
    print("It's a tie!")
elif (user == "rock" and computer == "scissors") or \
     (user == "paper" and computer == "rock") or \
     (user == "scissors" and computer == "paper"):
    print("You win!")
else:
    print("You lose!")
# Out:
# Enter choice (rock/paper/scissors):
# Computer chose: scissors
# You lose!
