# %% [markdown]
# <a href="https://colab.research.google.com/github/snehavyshnavi/Python/blob/main/FileReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filename = input("Enter filename: ")

try:
    with open(filename, "r") as file:
        content = file.read()
        print("\nFile Content:\n")
        print(content)
except FileNotFoundError:
    print("File not found!")
# Out:
# Enter filename: fsd
# File not found!
